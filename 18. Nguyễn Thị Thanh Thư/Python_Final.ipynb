# %%
# Thêm thư viện trong notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel ('Course_4.xlsx')
df
# Out:
#           Customer Name    Age                    Name of Industry  \
# 0           Claire Gute  35-44                               Buyer
# 1       Darrin Van Huff  45-54                 Veterinary medicine
# 2        Sean O'Donnell  35-44  "Government Relations" (Lobbying)
# 3       Brosina Hoffman  25-34                     Academia - STEM
# 4          Andrew Allen  25-34                 Academia / Research
# ..                  ...    ...                                 ...
# 923  Gabrielle Rampling  35-44                          Work-Study
# 924            Ava Gray  35-44             Writing and journalism
# 925     Harry Churchill  55-64                                 Zoo
# 926         Hannah Parr  35-44                  Zoos and Aquariums
# 927       Deirdre James  45-54                       Data Engineer
#
#                                       Job title  Annual salary Country  \
# 0                         Management assistant           76650     USA
# ...

# %%
# Thống kê các độ đo
df.describe()
# Out:
#        Annual salary        Sales
# count     928.000000   928.000000
# mean    77507.933190   238.633039
# std     42817.713864   598.468383
# min         0.000000     1.248000
# 25%     50000.000000    18.810000
# 50%     67000.000000    57.278000
# 75%     97000.000000   213.206250
# max    450000.000000  8159.952000

# %%
#Kiểm tra tính toàn vẹn của dữ liệu
df.describe().show()
# Out:
# Customer Name       0
# Age                 0
# Name of Industry    0
# Job title           0
# Annual salary       0
# Country             0
# Work experience     0
# Gender              0
# State               0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# dtype: int64

# %%
# Xoá cột [Country] không cần thiết
del df ['Country']

# %%
# Kiểm tra số người theo giới tính
df['Gender'].value_counts()
# Out:
# Woman    801
# Man      127
# Name: Gender, dtype: int64

# %%
# Kiểm tra số người theo độ tuổi
df['Age'].value_counts()
# Out:
# 25-34         395
# 35-44         325
# 45-54         126
# 55-64          45
# 18-24          31
# 65 or over      6
# Name: Age, dtype: int64

# %%
# Kiểm tra số người theo năm kinh nghiệm
df['Work experience'].value_counts()
# Out:
# 11 - 20 years       310
# 8 - 10 years        170
# 5-7 years           152
# 21 - 30 years       151
# 2 - 4 years          92
# 31 - 40 years        29
# 1 year or less       15
# 41 years or more      9
# Name: Work experience, dtype: int64

# %%
result = df.dtypes
result
# Out:
# Customer Name        object
# Age                  object
# Name of Industry     object
# Job title            object
# Annual salary         int64
# Work experience      object
# Gender               object
# State                object
# Category             object
# Sub-Category         object
# Product Name         object
# Sales               float64
# dtype: object

# %%
df.to_csv('Final.csv')
