# %%
# Thêm thư viện trong notebook
import pandas as pd
import numpy as np

# %%
# Đưa dữ liệu vào Python và đọc
df1 = pd.read_excel ("Final_Project_Dataset.xlsx")
df1
# Out:
#            CustomerName    Age                      NameOfIndustry  \
# 0           Claire Gute  35-44                               Buyer
# 1       Darrin Van Huff  45-54                 Veterinary medicine
# 2        Sean O'Donnell  35-44  "Government Relations" (Lobbying)
# 3       Brosina Hoffman  25-34                     Academia - STEM
# 4          Andrew Allen  25-34                 Academia / Research
# ..                  ...    ...                                 ...
# 923  Gabrielle Rampling  35-44                          Work-Study
# 924            Ava Gray  35-44             Writing and journalism
# 925     Harry Churchill  55-64                                 Zoo
# 926         Hannah Parr  35-44                  Zoos and Aquariums
# 927       Deirdre James  45-54                       Data Engineer
#
#                                        JobTitle  AnnualSalary WorkExperience  \
# 0                         Management assistant          76650  11 - 20 years
# 1                        Managing veterinarian         155000  31 - 40 years
# 2                                    Assistant          65000      5-7 years
# 3                   Graduate research assistant         32000    2 - 4 years
# 4                       Project manager senior          68500  11 - 20 years
# ..                                          ...           ...            ...
# 923                              Student Worker         16000  11 - 20 years
# 924  Tier 2 writer/ business writer pod manager         56000  21 - 30 years
# 925                                 Zoo curator         80000  31 - 40 years
# 926                                Zoo Educator         37419  11 - 20 years
# 927                            Proposal Manager         87938  21 - 30 years
#
#     Gender
# 0    Woman
# 1      Man
# 2    Woman
# 3    Woman
# 4    Woman
# ..     ...
# 923  Woman
# 924  Woman
# 925  Woman
# 926  Woman
# 927  Woman
#
# [928 rows x 7 columns]

# %%
df2 = pd.read_excel("SalebyCustomer.xlsx")
df2
# Out:
#       RowID         OrderID  OrderDate        ShipMode CustomerID  \
# 0         1  CA-2016-152156 2021-11-08    Second Class   CG-12520
# 1         2  CA-2016-152156 2021-11-08    Second Class   CG-12520
# 2         3  CA-2016-138688 2021-06-12    Second Class   DV-13045
# 3         4  US-2015-108966 2021-10-11  Standard Class   SO-20335
# 4         5  US-2015-108966 2021-10-11  Standard Class   SO-20335
# ...     ...             ...        ...             ...        ...
# 9988   9990  CA-2014-110422 2021-01-21    Second Class   TB-21400
# 9989   9991  CA-2017-121258 2021-02-26  Standard Class   DB-13060
# 9990   9992  CA-2017-121258 2021-02-26  Standard Class   DB-13060
# 9991   9993  CA-2017-121258 2021-02-26  Standard Class   DB-13060
# 9992   9994  CA-2017-119914 2021-05-04    Second Class   CC-12220
#
#           CustomerName    Segment        Country             City       State  \
# 0          Claire Gute   Consumer  United States        Henderson    Kentucky
# 1          Claire Gute   Consumer  United States        Henderson    Kentucky
# 2      Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# ...                ...        ...            ...              ...         ...
# 9988  Tom Boeckenhauer   Consumer  United States            Miami     Florida
# 9989       Dave Brooks   Consumer  United States       Costa Mesa  California
# 9990       Dave Brooks   Consumer  United States       Costa Mesa  California
# 9991       Dave Brooks   Consumer  United States       Costa Mesa  California
# 9992      Chris Cortes   Consumer  United States      Westminster  California
#
#       PostalCode Region        ProductID         Category Sub-Category  \
# 0          42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1          42420  South  FUR-CH-10000454        Furniture       Chairs
# 2          90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3          33311  South  FUR-TA-10000577        Furniture       Tables
# 4          33311  South  OFF-ST-10000760  Office Supplies      Storage
# ...          ...    ...              ...              ...          ...
# 9988       33180  South  FUR-FU-10001889        Furniture  Furnishings
# 9989       92627   West  FUR-FU-10000747        Furniture  Furnishings
# 9990       92627   West  TEC-PH-10003645       Technology       Phones
# 9991       92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9992       92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                             ProductName     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9988                             Ultra Door Pull Handle   25.2480         3
# 9989  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9990                              Aastra 57i VoIP phone  258.5760         2
# 9991  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9992  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45  383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9988      0.20    4.1028
# 9989      0.00   15.6332
# 9990      0.20   19.3932
# 9991      0.00   13.3200
# 9992      0.00   72.9480
#
# [9993 rows x 20 columns]

# %%
# Thống kê các độ đo dữ liệu hai bảng
df1.describe()
# Out:
#         AnnualSalary
# count     928.000000
# mean    77507.933190
# std     42817.713864
# min         0.000000
# 25%     50000.000000
# 50%     67000.000000
# 75%     97000.000000
# max    450000.000000

# %%
df2.describe()
# Out:
#              RowID    PostalCode         Sales     Quantity     Discount  \
# count  9993.000000   9993.000000   9993.000000  9993.000000  9993.000000
# mean   4997.624037  55191.593816    229.869885     3.789252     0.156198
# std    2885.281351  32065.067934    623.275155     2.224989     0.206462
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.000000  23223.000000     17.280000     2.000000     0.000000
# 50%    4998.000000  56560.000000     54.480000     3.000000     0.200000
# 75%    7496.000000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9993.000000
# mean     59.907061
# std     228.288086
# min       0.000000
# 25%       5.369000
# 50%      13.967200
# 75%      43.164000
# max    8399.976000

# %%
#Kiểm tra tính toàn vẹn của dữ liệu
df1.isnull().sum()
# Out:
# CustomerName      0
# Age               0
# NameOfIndustry    0
# JobTitle          0
# AnnualSalary      0
# WorkExperience    0
# Gender            0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# RowID           0
# OrderID         0
# OrderDate       0
# ShipMode        0
# CustomerID      0
# CustomerName    0
# Segment         0
# Country         0
# City            0
# State           0
# PostalCode      0
# Region          0
# ProductID       0
# Category        0
# Sub-Category    0
# ProductName     0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Xoá cột không cần thiết
del df1 ['NameOfIndustry']
del df1 ['JobTitle']

# %%
del df2 ['RowID']
del df2 ['OrderID']
del df2 ['CustomerID']
del df2 ['ProductID']

# %%
# Xuất file csv sau khi xử lý
df1.to_csv('Dataset1.csv')

# %%
df2.to_csv('Dataset2.csv')
